# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load and check file1.csv
file1_cleaned = pd.read_csv(r"C:\Users\priya\Documents\Week_1\Day_3\Afternoon\lab-dw-data-cleaning-and-formatting\cleaned_insurance_data.csv")
display(file1_cleaned)
# Out:
#      customer       state gender             education  \
# 0     RB50392  WASHINGTON      F                Master
# 1     QZ44356     ARIZONA      F              Bachelor
# 2     AI49188      NEVADA      F              Bachelor
# 3     WW63253  CALIFORNIA      M              Bachelor
# 4     GA49547  WASHINGTON      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      OREGON      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     ARIZONA      F              Bachelor
# 1069  CW49887  CALIFORNIA      F                Master
# 1070  MY31220  CALIFORNIA      F               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      793690       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
#Check value_count for file1_cleaned.columns
for column in file1_cleaned.columns:
    print(f"Value counts for {column}:")
    print(file1_cleaned[column].value_counts())
    print("\n")
# Out:
# Value counts for customer:
# customer
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: count, Length: 1071, dtype: int64
#
#
# Value counts for state:
# state
# OREGON        320
# CALIFORNIA    211
# ARIZONA       186
# California    120
# NEVADA         98
# WASHINGTON     81
# Washington     30
# Arizona        25
# Name: count, dtype: int64
#
#
# Value counts for gender:
# gender
# F    619
# M    452
# Name: count, dtype: int64
#
#
# Value counts for education:
# education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 445811     4
# 251459     4
# 793690     3
# 2412750    3
# 684615     3
#           ..
# 1210120    1
# ...

# %%
file1_cleaned['state'] = file1_cleaned['state'].str.capitalize()

# Replace 'Bachelors' with 'Bachelor' in the 'education' column
file1_cleaned['education'] = file1_cleaned['education'].replace({'BACHELORS': 'BACHELOR'})

state_value_counts = file1_cleaned['state'].value_counts()
print(state_value_counts)
# Out:
# state
# California    331
# Oregon        320
# Arizona       211
# Washington    111
# Nevada         98
# Name: count, dtype: int64

# %%
# load and check file2.csv
file_2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
display(file_2)
file_2.isnull().sum()
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
# load and check file1.csv
file_3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')
display(file_3)
file_3.isnull().sum()
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# checking dataframes's info
display(file1_cleaned.info())
display(file_2.info())
display(file_3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071 entries, 0 to 1070
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   gender                     1071 non-null   object
#  3   education                  1071 non-null   object
#  4   customer_lifetime_value    1071 non-null   int64
#  5   income                     1071 non-null   int64
#  6   monthly_premium_auto       1071 non-null   int64
#  7   number_of_open_complaints  1071 non-null   int64
#  8   policy_type                1071 non-null   object
#  9   vehicle_class              1071 non-null   object
#  10  total_claim_amount         1071 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 92.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# ...

# %%
# checking columns names of file1_cleaned, file_2, file_3
display(file1_cleaned.columns)
display(file_2.columns)
display(file_3.columns)
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
# convert column names to lower case
file_2.columns = file_2.columns.str.lower().str.replace(' ', '_')
file_3.columns = file_3.columns.str.lower().str.replace(' ', '_')
file_2 = file_2.rename(columns = {'st' : 'state'})
display(file_2.columns)
display(file_3.columns)
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
#check after clean_column
display(file1_cleaned.columns)
display(file_2.columns)
display(file_3.columns)

# checking whether column names match
display(file1_cleaned.columns == file_2.columns)
display(file1_cleaned.columns == file_3.columns)
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')
# array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False])
# array([ True,  True, False,  True, False,  True,  True,  True,  True,
#        False, False])

# %%
#re-positioning columns in file 2, file 3 to match file 1

file_2 = file_2[list(file1_cleaned.columns)]
display(file_2)

file_3 = file_3[list(file1_cleaned.columns)]
display(file_3)


#check for column name
display(file1_cleaned.columns == file_2.columns)
display(file1_cleaned.columns == file_3.columns)
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
# CLEAN FILE_2

# %%
#Check value_count for file_2.columns
for column in file_2.columns:
    print(f"Value counts for {column}:")
    print(file_2[column].value_counts())
    print("\n")
# Out:
# Value counts for customer:
# customer
# GS98873    1
# MI62456    1
# SB50826    1
# XX29952    1
# AT93647    1
#           ..
# ZI47663    1
# GO14008    1
# BC43958    1
# AI61368    1
# SA91515    1
# Name: count, Length: 996, dtype: int64
#
#
# Value counts for state:
# state
# Oregon        303
# California    277
# Arizona       142
# Nevada        125
# Washington    100
# AZ             49
# Name: count, dtype: int64
#
#
# Value counts for gender:
# gender
# F         527
# M         461
# female      2
# Male        1
# Name: count, dtype: int64
#
#
# Value counts for education:
# education
# College                 311
# High School or Below    290
# Bachelor                243
# Master                   86
# Doctor                   49
# Bachelors                17
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 552821.28%     4
# 600521.48%     3
# 538949.95%     3
# 1203662.05%    3
# 871704.98%     3
# ...

# %%
# correct 'state' AZ to Arizona
file_2['state'] = file_2['state'].apply(lambda x: 'Arizona' if str(x) == 'AZ' else str(x))
file_2['state'].value_counts()

# Clean inconsistent values in the 'gender' column
file_2['gender'] = file_2['gender'].str.upper().replace({'female': 'F', 'Male': 'M', 'male': 'M'})


# correct 'education' Bachelors --> Bachelor
file_2['education'] = file_2['education'].apply(lambda x: 'Bachelor' if str(x) == 'Bachelors' else str(x))
file_2['education'].value_counts()

# clean 'customer_lifetime_value'
file_2['customer_lifetime_value'] = file_2['customer_lifetime_value'].apply(lambda x: str(x).replace('%','') if ('%' in str(x)) else str(x))
file_2['customer_lifetime_value'] = file_2['customer_lifetime_value'].astype('float64')

# clean 'number_of_open_complaints'
file_2['number_of_open_complaints'] = file_2['number_of_open_complaints'].apply(lambda x: int(str(x).split('/')[1]) if pd.notnull(x) and '/' in str(x) else x)
display(file_2['number_of_open_complaints'].value_counts()) # check counts and unique values after correcting

# clean 'vehicle_class': to luxury
file_2['vehicle_class'] = file_2['vehicle_class'].apply(lambda x: 'Luxury' if x in ['Sports Car', 'Luxury SUV', 'Luxury Car'] else x)
file_2['vehicle_class'].value_counts()


# drop na
file_2 = file_2.dropna()
file_2 = file_2.reset_index()

# dop column 'index'
file_2 = file_2.drop(columns='index')
file_2

# convert all numeric columns to integer
file_2 = file_2.applymap(lambda x: int(x) if isinstance(x, (float,int)) else x)
display(file_2.dtypes)
# Out:
# number_of_open_complaints
# 0    796
# 1    109
# 2     43
# 3     26
# 4     16
# 5      6
# Name: count, dtype: int64
# customer                     object
# state                        object
# gender                       object
# education                    object
# customer_lifetime_value       int64
# income                        int64
# monthly_premium_auto          int64
# number_of_open_complaints     int64
# policy_type                  object
# vehicle_class                object
# total_claim_amount            int64
# dtype: object

# %%
file_2cleaned = file_2.copy()
display(file_2cleaned)
# Out:
#     customer       state gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                   323912   16061
# 1    CW49887  California      F    Master                   462680   79487
# 2    MY31220  California      F   College                   899704   54230
# 3    UH35128      Oregon      F   College                  2580706   71210
# 4    WH52799     Arizona      F   College                   380812   94903
# ..       ...         ...    ...       ...                      ...     ...
# 983  HV85198     Arizona      M    Master                   847141   63513
# 984  BS91566     Arizona      F   College                   543121   58161
# 985  IL40123      Nevada      F   College                   568964   83640
# 986  MY32149  California      F    Master                   368672       0
# 987  SA91515  California      M  Bachelor                   399258       0
#
# ...

# %%
#CLEAN FILE_3

# %%
#Check value_count for file_3.columns
for column in file_3.columns:
    print(f"Value counts for {column}:")
    print(file_3[column].value_counts())
    print("\n")
# Out:
# Value counts for customer:
# customer
# SA25987    1
# EO99750    1
# JM98365    1
# QI11566    1
# VG43444    1
#           ..
# TR96772    1
# JU64043    1
# ZE59592    1
# FT74388    1
# Y167826    1
# Name: count, Length: 7070, dtype: int64
#
#
# Value counts for state:
# state
# California    2544
# Oregon        1978
# Arizona       1302
# Nevada         659
# Washington     587
# Name: count, dtype: int64
#
#
# Value counts for gender:
# gender
# F    3576
# M    3494
# Name: count, dtype: int64
#
#
# Value counts for education:
# education
# Bachelor                2152
# College                 2058
# High School or Below    2030
# Master                   572
# Doctor                   258
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 2647.519741     6
# 2659.705650     6
# 4686.469674     6
# 4270.034394     6
# 13727.799720    6
#                ..
# 11281.524510    1
# 8759.592518     1
# 4928.001408     1
# ...

# %%
file_3.info()
# file_3 has no null value

# to clean for file_3
# 1. column 'vehicle_class'
file_3['vehicle_class'] = file_3['vehicle_class'].apply(lambda x: 'Luxury' if x in ['Sports Car', 'Luxury SUV', 'Luxury Car'] else x)
file_3['vehicle_class'].value_counts()

# 2. cast all numeric columns to int64
file_3 = file_3.applymap(lambda x: int(x) if isinstance(x, (float,int)) else x)
display(file_3.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   7070 non-null   object
#  1   state                      7070 non-null   object
#  2   gender                     7070 non-null   object
#  3   education                  7070 non-null   object
#  4   customer_lifetime_value    7070 non-null   float64
#  5   income                     7070 non-null   int64
#  6   monthly_premium_auto       7070 non-null   int64
#  7   number_of_open_complaints  7070 non-null   int64
#  8   policy_type                7070 non-null   object
#  9   vehicle_class              7070 non-null   object
#  10  total_claim_amount         7070 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB
# customer                     object
# state                        object
# ...

# %%
file_3cleaned = file_3.copy()
display(file_3cleaned)
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                        3479       0                   104
# 1                        2502       0                    66
# 2                        3265   25820                    82
# ...

# %%
#Combining file1_cleaned, file_2cleaned, file_3cleaned into Merged_file
Merged_file = pd.concat([file1_cleaned, file_2cleaned, file_3cleaned], axis = 0)
Merged_file
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      793690       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
#Check for NA after concatenate files
Merged_file.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
# Check for duplicates in Merged_file
Merged_file.duplicated().sum()
# Out:
# 1

# %%
#Check value_count for Merged_file.columns
for column in Merged_file.columns:
    print(f"Value counts for {column}:")
    print(Merged_file[column].value_counts())
    print("\n")
# Out:
# Value counts for customer:
# customer
# BJ22117    2
# FM14335    2
# GX84338    2
# KN13494    2
# LR10110    2
#           ..
# JD11661    1
# QM39493    1
# DW62397    1
# WC77067    1
# Y167826    1
# Name: count, Length: 9051, dtype: int64
#
#
# Value counts for state:
# state
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     790
# Name: count, dtype: int64
#
#
# Value counts for gender:
# gender
# F         4721
# M         4405
# FEMALE       2
# MALE         1
# Name: count, dtype: int64
#
#
# Value counts for education:
# education
# Bachelor                2732
# College                 2681
# High School or Below    2614
# Master                   751
# Doctor                   344
# Bachelors                  7
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 6005     11
# 3237      9
# 2719      9
# 8382      9
# 2619      9
#          ..
# 15122     1
# 19643     1
# ...

# %%
# Clean inconsistent values in the 'gender' column
Merged_file['gender'] = Merged_file['gender'].replace({'MALE': 'M', 'FEMALE': 'F'})

# Clean values in 'vehicle_class'
Merged_file['vehicle_class'] = Merged_file['vehicle_class'].str.capitalize()


# Replace 'Bachelors' with 'Bachelor' in the 'education' column
Merged_file['education'] = Merged_file['education'].replace({'Bachelors': 'Bachelor'})

value_counts = Merged_file['education'].value_counts()
print(value_counts)
# Out:
# education
# Bachelor                2739
# College                 2681
# High School or Below    2614
# Master                   751
# Doctor                   344
# Name: count, dtype: int64

# %%
#Check value_count for Merged_file.columns
for column in Merged_file.columns:
    print(f"Value counts for {column}:")
    print(Merged_file[column].value_counts())
    print("\n")
# Out:
# Value counts for customer:
# customer
# BJ22117    2
# FM14335    2
# GX84338    2
# KN13494    2
# LR10110    2
#           ..
# JD11661    1
# QM39493    1
# DW62397    1
# WC77067    1
# Y167826    1
# Name: count, Length: 9051, dtype: int64
#
#
# Value counts for state:
# state
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     790
# Name: count, dtype: int64
#
#
# Value counts for gender:
# gender
# F    4723
# M    4406
# Name: count, dtype: int64
#
#
# Value counts for education:
# education
# Bachelor                2739
# College                 2681
# High School or Below    2614
# Master                   751
# Doctor                   344
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 6005     11
# 3237      9
# 2719      9
# 8382      9
# 2619      9
#          ..
# 15122     1
# 19643     1
# 2957      1
# 36897     1
# 8163      1
# ...

# %%
# Check for duplicates in Merged_file
Merged_file.duplicated().sum()

# drop duplicates in Merged_file
Merged_file = Merged_file.drop_duplicates()

# check after drop
Merged_file.duplicated().sum()
# Out:
# 0

# %%
# Reset index of Merged_file
Merged_file = Merged_file.reset_index()
#merged_df

#drop the index column
Merged_file = Merged_file.drop (columns = 'index')
Merged_file
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9121  LA72316  California      M              Bachelor
# 9122  PK87824  California      F               College
# 9123  TD14365  California      M              Bachelor
# 9124  UP19263  California      M               College
# 9125  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      793690       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
#Check info of Merged_file
Merged_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9126 entries, 0 to 9125
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9126 non-null   object
#  1   state                      9126 non-null   object
#  2   gender                     9126 non-null   object
#  3   education                  9126 non-null   object
#  4   customer_lifetime_value    9126 non-null   int64
#  5   income                     9126 non-null   int64
#  6   monthly_premium_auto       9126 non-null   int64
#  7   number_of_open_complaints  9126 non-null   int64
#  8   policy_type                9126 non-null   object
#  9   vehicle_class              9126 non-null   object
#  10  total_claim_amount         9126 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 784.4+ KB

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
#load and check marketing_customer_analysis.csv
marketing_customer_df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
marketing_customer_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#Checking info about marketing_customer_df
marketing_customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
#Check value_count for marketing_customer_df.columns
for column in marketing_customer_df.columns:
    print(f"Value counts for {column}:")
    print(marketing_customer_df[column].value_counts())
    print("\n")
# Out:
# Value counts for unnamed:_0:
# unnamed:_0
# 0        1
# 7276     1
# 7268     1
# 7269     1
# 7270     1
#         ..
# 3638     1
# 3639     1
# 3640     1
# 3641     1
# 10909    1
# Name: count, Length: 10910, dtype: int64
#
#
# Value counts for customer:
# customer
# ID89933    7
# DQ50258    5
# AM79057    5
# FP86246    5
# KE35335    4
#           ..
# VW27730    1
# ZX64745    1
# CK24264    1
# IX18485    1
# WA60547    1
# Name: count, Length: 9134, dtype: int64
#
#
# Value counts for state:
# state
# California    4183
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64
#
#
# Value counts for customer_lifetime_value:
# customer_lifetime_value
# 7507.455372     11
# 5504.139033     11
# 5181.620895     10
# 13727.799720    10
# 5332.462694     10
#                 ..
# 3467.323976      1
# 14140.558850     1
# 20018.204590     1
# 7432.299921      1
# 11971.977650     1
# Name: count, Length: 8041, dtype: int64
# ...

# %%
#Need to delete unnamed:_0 column
marketing_customer_df_clean = marketing_customer_df.drop(columns='unnamed:_0')
marketing_customer_df_clean
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
#Column 'effective_to_date' should be in datetime format, yyyy-mm-dd

marketing_customer_df_clean['effective_to_date'] = pd.to_datetime(marketing_customer_df['effective_to_date'], errors='coerce')
#display(marketing_customer_df_clean.head())       

#print(marketing_customer_df.dtypes)
#print(marketing_customer_df_clean.dtypes)

#column 'months_since_last_claim' (col[14]) --> dtype change to int64

#marketing_customer_df['months_since_last_claim']= marketing_customer_df['months_since_last_claim'].applymap(lambda x:int(x) if isinstance (x, (float,int)) else x) 
marketing_customer_df_clean['months_since_last_claim'] = marketing_customer_df['months_since_last_claim'].round().astype('int64') 

#display(marketing_customer_df_clean['months_since_last_claim'].value_counts())
#display(type(marketing_customer_df['months_since_last_claim']))

#The current dtype is float64. This should be int64, not a float64 number as you can not have a half of a complaint.
marketing_customer_df_clean['number_of_open_complaints'] = marketing_customer_df['number_of_open_complaints'].round().astype('int64') 

#Change column name 'employmentstatus' with '_' for the consistency of column name
marketing_customer_df_clean=marketing_customer_df_clean.rename(columns = {'employmentstatus': 'employment_status'})

#Values in 'vehicle_class': 'Sport cars', 'luxury SUV', and 'luxury' could be replaced by 'luxury'
marketing_customer_df_clean['vehicle_class']=marketing_customer_df_clean['vehicle_class'].apply(lambda x: 'Luxury' if x in ['Sports Car', 'Luxury SUV', 'Luxury Car'] else x) 
#display(marketing_customer_df_clean['vehicle_class'].value_counts())

#Column vehicle_size: replace 'medsize' with 'Medium'
marketing_customer_df_clean['vehicle_size'] = marketing_customer_df_clean['vehicle_size'].apply(lambda x: 'Medium' if x == 'Medsize' else x )
display(marketing_customer_df_clean['vehicle_size'].value_counts())

#print(marketing_customer_df_clean.dtypes)
display(marketing_customer_df_clean.head())
# Out:
# vehicle_size
# Medium    7873
# Small     1966
# Large     1071
# Name: count, dtype: int64
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employment_status gender  income  ... number_of_policies  \
# 0        2011-02-18          Employed      M   48029  ...                  9
# 1        2011-01-18        Unemployed      F       0  ...                  1
# 2        2011-02-10          Employed      M   22139  ...                  2
# 3        2011-01-11          Employed      M   49078  ...                  2
# ...

# %%
display(marketing_customer_df_clean)
display(marketing_customer_df_clean.dtypes)
display(marketing_customer_df_clean.info())
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employment_status gender  income  ...  \
# ...

# %%
marketing_customer_df_clean.to_csv("marketing_customer_analysis_clean.csv", index = False)

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 32F0-16BF
#
#  Directory of C:\Users\priya\Documents\Week_1\Day_4\Morning\lab-dw-data-structuring-and-combining
#
# 12/12/2023  21:01    <DIR>          .
# 07/12/2023  00:13    <DIR>          ..
# 07/12/2023  00:13             6.148 .DS_Store
# 07/12/2023  00:17    <DIR>          .ipynb_checkpoints
# 12/12/2023  21:01            97.316 lab-dw-data-structuring-and-combining.ipynb
# 12/12/2023  21:01         1.962.363 marketing_customer_analysis_clean.csv
# 07/12/2023  00:13             8.160 README.md
#                4 File(s)      2.073.987 bytes
#                3 Dir(s)  265.457.340.416 bytes free

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# Create the pivot table
pivot_table_sales_channel = pd.pivot_table(marketing_customer_df_clean, values='total_claim_amount', index='sales_channel', aggfunc='sum')

# Round the total revenue to 2 decimal points
pivot_table_sales_channel['total_revenue'] = pivot_table_sales_channel['total_claim_amount'].round(2)

# Display the pivot table
display(pivot_table_sales_channel)
# Out:
#                total_claim_amount  total_revenue
# sales_channel
# Agent                1.810227e+06     1810226.82
# Branch               1.301204e+06     1301204.00
# Call Center          9.266008e+05      926600.82
# Web                  7.066000e+05      706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
#Average customer lifetime value per gender and education level
#np.round(marketing_customer_df_clean.pivot_table(index = ['gender', 'education'], values = 'customer_lifetime_value'),2)

pivot_table = pd.pivot_table(marketing_customer_df_clean, values='customer_lifetime_value', index=['gender', 'education'], aggfunc='mean')
display(pivot_table)
# Out:
#                              customer_lifetime_value
# gender education
# F      Bachelor                          7874.269478
#        College                           7748.823325
#        Doctor                            7328.508916
#        High School or Below              8675.220201
#        Master                            8157.053154
# M      Bachelor                          7703.601675
#        College                           8052.459288
#        Doctor                            7415.333638
#        High School or Below              8149.687783
#        Master                            8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
#Check this dataset is from one year or from multiple years
check = pd.DataFrame()
check['year'] = marketing_customer_df_clean['effective_to_date'].dt.year
check.value_counts()

#column named 'effective_to_month' which extracts month from 'effective_to_date'
marketing_customer_df_clean['effective_to_month'] = marketing_customer_df_clean['effective_to_date'].dt.month

#table with total complaints by policy type and month
total_complaints_by_policy_type_and_month = marketing_customer_df_clean.groupby(['policy_type','effective_to_month' ]).agg({'number_of_open_complaints':'sum'})
display(total_complaints_by_policy_type_and_month.head())

#test to change result into long format

test = total_complaints_by_policy_type_and_month.reset_index()
display(test.head())

pd.melt(test, id_vars = ['policy_type'], value_vars = ['effective_to_month','number_of_open_complaints'] )
# Out:
#                                    number_of_open_complaints
# policy_type    effective_to_month
# Corporate Auto 1                                         415
#                2                                         361
# Personal Auto  1                                        1635
#                2                                        1363
# Special Auto   1                                          84
#       policy_type  effective_to_month  number_of_open_complaints
# 0  Corporate Auto                   1                        415
# 1  Corporate Auto                   2                        361
# 2   Personal Auto                   1                       1635
# 3   Personal Auto                   2                       1363
# 4    Special Auto                   1                         84
#        policy_type                   variable  value
# 0   Corporate Auto         effective_to_month      1
# 1   Corporate Auto         effective_to_month      2
# ...
